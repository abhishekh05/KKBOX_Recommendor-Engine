# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['song_extra_info.csv', 'members.csv', 'train.csv', 'test.csv', 'songs.csv']

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))
# Out:
# members.csv
# song_extra_info.csv
# songs.csv
# test.csv
# train.csv

# %%
train = pd.read_csv('../input/train.csv')
songs = pd.read_csv('../input/songs.csv')
test = pd.read_csv('../input/test.csv')
members = pd.read_csv('../input/members.csv')
songs_extra_info = pd.read_csv('../input/song_extra_info.csv')

# %%
df = train.merge(members,how='inner',on='msno')
df = df.merge(songs,how='inner',on='song_id')
df.head()
# Out:
#                                            msno   ...    language
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=   ...        52.0
# 1  pouJqjNRmZOnRNzzMWWkamTKkIGHyvhl/jo4HgbncnM=   ...        52.0
# 2  xbodnNBaLMyqqI7uFJlvHOKMJaizuWo/BB/YHZICcKo=   ...        52.0
# 3  s0ndDsjI79amU0RBiullFN8HRz9HjE++34jGNa7zJ/s=   ...        52.0
# 4  Vw4Umh6/qlsJDC/XMslyAxVvRgFJGHr53yb/nrmY1DU=   ...        52.0
#
# [5 rows x 18 columns]

# %%
# !pip install ../input/recommender-system/RecommenderSystems_PyData_2016-master/RecommenderSystems_PyData_2016-master/Evaluation.py
# Out:
# Invalid requirement: '../input/recommender-system/RecommenderSystems_PyData_2016-master/RecommenderSystems_PyData_2016-master/Evaluation.py'
# It looks like a path. File '../input/recommender-system/RecommenderSystems_PyData_2016-master/RecommenderSystems_PyData_2016-master/Evaluation.py' does not exist.

# %%
df.columns
# Out:
# Index(['msno', 'song_id', 'source_system_tab', 'source_screen_name',
#        'source_type', 'target', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date', 'song_length', 'genre_ids',
#        'artist_name', 'composer', 'lyricist', 'language'],
#       dtype='object')

# %%
df = train.merge(members,how='inner',on='msno')
df = df.merge(songs,how='inner',on='song_id')
df.drop_duplicates(subset =['source_system_tab', 'source_screen_name',
       'source_type', 'target', 'city', 'bd', 'gender', 'registered_via',
       'registration_init_time', 'expiration_date', 'song_length', 'genre_ids',
       'artist_name', 'composer', 'lyricist', 'language'], 
                     keep = False, inplace = True) 
df.reset_index(drop = True,inplace=True)
df
# Out:
#                                                  msno   ...    language
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=   ...        52.0
# 1        pouJqjNRmZOnRNzzMWWkamTKkIGHyvhl/jo4HgbncnM=   ...        52.0
# 2        xbodnNBaLMyqqI7uFJlvHOKMJaizuWo/BB/YHZICcKo=   ...        52.0
# 3        s0ndDsjI79amU0RBiullFN8HRz9HjE++34jGNa7zJ/s=   ...        52.0
# 4        Vw4Umh6/qlsJDC/XMslyAxVvRgFJGHr53yb/nrmY1DU=   ...        52.0
# 5        YqtKhiDOFJ/gdd2V4AFdnVwGMMaA0yUEbb8w7xuoP7I=   ...        52.0
# 6        jGiECz8y+oKS0tDcZArJXK2ZQisBpk/OC3wh4kvs8gc=   ...        52.0
# 7        ruQx4VOdTq74CDI1viGqQAIASWrU4soi74t1E3N6KO4=   ...        52.0
# 8        7xiBI5xU3P2/IiR9teB7jySfzWo96JGikGajteLd3Cs=   ...        52.0
# 9        z2IYoGWjJJPv4ySp+1lCIfU1APu2YRHsjY2sy2ehq0k=   ...        52.0
# 10       oKMHFr1nozVUOW4TP9bcbtVhgCt5gh+22fJ1mUXx9eM=   ...        52.0
# 11       e5Ezre9HPuPos+CXQXtmo32E/hHIZTMmo6jG3yRf6UA=   ...        52.0
# 12       tlFGRF/TtrSwJA9XPHL4cajWghZCbAbhzif/6wJiN6Q=   ...        52.0
# 13       Gytn0lz9OGR2vGl/tSXA3rDUcNnU4TnxFcWb+iv2pXc=   ...        52.0
# 14       pRHIP4XdwWx7YpREsLN4sD0gb2BUEbhKytDXlwUAO+k=   ...        52.0
# 15       vf72WjMnAjr9ELP36xOjbCXhXQTk2qCQ1MW56xKT12s=   ...        52.0
# 16       cArsboqFz/6anddpnMwh2OptGbYB+mT3yeSNV7XxrRA=   ...        52.0
# 17       ERpPeskmIkU3MrJxl9BQjGn2a/Nqv72E77hFyxQ8iY8=   ...        52.0
# 18       8Hh8B3UZRBATg+WAHfE+sZ2hHeqT7QMDr8PdiWFPESE=   ...        52.0
# 19       /tFG33EMQ6m1ZBY2RbFIqKqyhwqnx8qL1VzHdWkAuMA=   ...        52.0
# 20       a1d2KnoIq+/QdPaHUojFU7jnze1HDUxu5VFHJ2hti2w=   ...        52.0
# 21       MfpAwtL9uoZ+5z/zTuGOcGbNh45v7MeJ+cbJlb/14X4=   ...        52.0
# 22       MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=   ...        52.0
# 23       Zy0Nxvr1rTLpf85L79dMsVF6mPvVY3YgN6TgNwza7oI=   ...        52.0
# 24       wlGXXGn+a4va5/R4HWuk+ttkMp48ccj5FRjjPLAh2mI=   ...        52.0
# 25       R7AyK9ZUi5d21sCDumgghXW+TNacd/qN0dNMa0C22pA=   ...        52.0
# 26       kOXcer+//oOLtOB6JLhxNqj/3YyTH2m+kWfvYTtMc7I=   ...        52.0
# 27       CQSbIGpOs0ZOz578sAij/5djDLEnvAsxAtfByXc9JiU=   ...        52.0
# 28       yCsfLrK6TZNPAPbu0TFv+kwv/3CFTNMGRFpFCahPiqs=   ...        52.0
# 29       1NBzQ4hbG65uz/esF0hMF9kXDLTNKLdI06S06nJZ/Kk=   ...        52.0
# ...                                               ...   ...         ...
# 7323011  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323012  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323013  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323014  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323015  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323016  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323017  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        -1.0
# 7323018  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323019  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323020  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        31.0
# 7323021  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        -1.0
# 7323022  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        31.0
# 7323023  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323024  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323025  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323026  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323027  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        17.0
# 7323028  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323029  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        17.0
# 7323030  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323031  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323032  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=   ...        52.0
# 7323033  EwQCy6vvSqKWBYZuSB/xofq1h8nBT9ZYaWEFymts4t0=   ...        52.0
# 7323034  4jdyQwahZh2lhs08UdnDbu+DqaCJgoPFOrPp83W+044=   ...        52.0
# 7323035  b+zlHeMVMrhQObGieK6wDNRuoe8heCGVYD74kejsxyk=   ...        52.0
# 7323036  QPrVEVrWZBD2+QNPnzxHWAUUHd2IpicbPcd99Eqf7LY=   ...         3.0
# 7323037  Bz0puqoyfJ+pjRAH0UZy6TUaZyoNyH6vrFs97ivG/0c=   ...        52.0
# 7323038  vKFLRCvickoFcCoGgv5BT/kuH/XWqofuTm9JWkaFybM=   ...        24.0
# 7323039  IAUJlwmr/sjXUg+mHdWpLIjeFLkS0nv3kE5SI6xipuQ=   ...        24.0
# 7323040  IAUJlwmr/sjXUg+mHdWpLIjeFLkS0nv3kE5SI6xipuQ=   ...        59.0
#
# [7323041 rows x 18 columns]

# %%
sa=df[['msno','song_id','artist_name']]
sa1=df[['msno','song_id']]

sa = sa.groupby(['msno','artist_name']).count()
sa1 = sa1.groupby('msno').count()
sa1



sa.reset_index('artist_name',inplace=True)

sa

final = sa.merge(sa1, left_index=True, right_index=True, how='left')

final['normalized']=final['song_id_x']/final['song_id_y']

final.reset_index('msno',inplace=True)

final = final[['msno','artist_name','normalized']]
final

#final.pivot(index='msno', columns='artist_name', values='normalized')
# Out:
#                                                  msno    ...     normalized
# 0        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.006814
# 1        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 2        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 3        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.005111
# 4        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.030664
# 5        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 6        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 7        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.080068
# 8        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 9        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 10       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.003407
# 11       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 12       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 13       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.005111
# 14       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.005111
# 15       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.057922
# 16       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.003407
# 17       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 18       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 19       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 20       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 21       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 22       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 23       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.034072
# 24       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 25       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 26       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 27       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 28       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.001704
# 29       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=    ...       0.023850
# ...                                               ...    ...            ...
# 3105174  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.041509
# 3105175  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105176  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105177  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105178  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105179  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105180  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105181  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105182  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105183  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105184  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105185  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105186  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105187  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105188  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105189  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105190  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105191  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105192  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105193  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105194  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.007547
# 3105195  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105196  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105197  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105198  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.015094
# 3105199  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.003774
# 3105200  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=    ...       0.011321
# 3105201  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=    ...       0.333333
# 3105202  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=    ...       0.333333
# 3105203  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=    ...       0.333333
#
# [3105204 rows x 3 columns]

# %%
final = final.set_index('msno')
final
# Out:
#                                                                                    artist_name  normalized
# msno
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                           50 Cent    0.006814
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                             A-Lin    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                             Adele    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                              Akon    0.005111
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                       Alan Walker    0.030664
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                               Alice In Wonderland    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                              Aqua    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                     Avril Lavigne    0.080068
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                        Ayaka (絢香)    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                       Christopher    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                          Coldplay    0.003407
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                          Dimitri Vegas| Like Mike    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                       Duran Duran    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                            Eminem    0.005111
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                 Far East Movement    0.005111
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                          Flo Rida    0.057922
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                         G.E.M.鄧紫棋    0.003407
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                             Grits    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                         Hairspray    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                          Hardwell    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                     ItaloBrothers    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                     L'Arc～en～Ciel    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                             LMFAO    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                       Linkin Park    0.034072
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                        M.C.Hammer    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                           Madonna    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                         Martin Garrix| Bebe Rexha    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                            Matzka    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=  Music And Lyrics - Music From The Motion Picture    0.001704
# ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=                                           Pitbull    0.023850
# ...                                                                                        ...         ...
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                  蔡健雅 (Tanya Chua)    0.041509
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                          蔣卓嘉 (GJ)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                  蕭亞軒 (Elva Hsiao)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                   蕭敬騰 (Jam Hsiao)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                   薛凱琪 (Fiona Sit)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                   蘇打綠 (Sodagreen)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                          蘭陵王電視原聲帶    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                     謝和弦 (R-chord)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                     謝安琪 (Kay Tse)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                謝霆鋒 (Nicholas Tse)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                   謝震廷 (Eli Hsieh)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                    譚詠麟 (Alan Tam)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                                趙傳    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                               路嘉欣    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                   郭靜 (Claire Kuo)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                陳偉霆 (William Chan)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                  陳勢安 (Andrew Tan)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                  陳奕迅 (Eason Chan)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                    陳彥允 (Ian Chen)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                 陳珊妮 (Sandee Chan)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                   陳芳語 (Kimberley)    0.007547
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                            電影【念念】    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                 韋禮安 (William Wei)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                         風中奇緣電視原聲帶    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                               馬天宇    0.015094
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                       麋先生 (Mixer)    0.003774
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=                                     黎明 (Leon Lai)    0.011321
# zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=                                三個人 (Three People)    0.333333
# zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=                                        田馥甄 (Hebe)    0.333333
# zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=                                     謝和弦 (R-chord)    0.333333
#
# [3105204 rows x 2 columns]

# %% [markdown]
# 222363 unique artists

# %%
artist_songs = songs[['artist_name','song_id']].groupby(['artist_name']).count().sort_values('song_id', ascending=False)

# %%
artist_songs
# Out:
#                                                     song_id
# artist_name
# Various Artists                                      145916
# 証聲音樂圖書館 ECHO MUSIC                                    11276
# Billy Vaughn                                           4828
# รวมศิลปิน                                              4432
# Richard Clayderman                                     4180
# Elvis Presley                                          4038
# Nat King Cole                                          3806
# Billie Holiday                                         3674
# Frank Sinatra                                          3594
# Armin van Buuren                                       2818
# Various                                                2742
# Ella Fitzgerald                                        2721
# オルゴールサウンド J-POP                                        2692
# Glenn Gould                                            2689
# Bill Evans                                             2572
# Chet Baker                                             2532
# 鄧麗君 (Teresa Teng)                                      2487
# Bob Dylan                                              2471
# 貴族精選                                                   2419
# Ray Charles                                            2235
# The Kiboomers                                          2230
# Michael Jackson                                        2208
# Miles Davis                                            2179
# Falcom Sound Team jdk                                  2164
# Louis Armstrong                                        2161
# Wolfgang Amadeus Mozart                                2047
# Andy Williams                                          1995
# Power Music Workout                                    1987
# 霹靂布袋戲劇集原聲帶                                             1905
# Julie London                                           1838
# ...                                                     ...
# Mariachi Bandido                                          1
# Bloody Merry                                              1
# Blood|Impetigo                                            1
# Mariachi                                                  1
# Mariaca Semprun| Hugo Fuguet                              1
# Maria-Joao Pires| Theodor Guschlbauer & Gulbenk...        1
# Maria-Joao Pires| Armin Jordan & Lausanne Chamb...        1
# Maria-Hélèna Pacelli                                      1
# Blooming Bones                                            1
# Maria Weir| Jack Knight                                   1
# Maria Vargo                                               1
# Maria Valeria                                             1
# Maria Timm                                                1
# Maria Teresa Vera                                         1
# Maria Teresa Torelli                                      1
# Bloom| Dylan Brady                                        1
# Maria Tanase                                              1
# Maria Stader                                              1
# Maria Scivittaro| André Collard                           1
# Maria Sadowska                                            1
# Maria Rosé                                                1
# Maria Rodés                                               1
# Maria Razumovskaya                                        1
# Maria Popova                                              1
# Maria Pikoula                                             1
# Maria Perrotta                                            1
# Maria Paloma and Sleep Baby Sleep                         1
# Blory                                                     1
# Maria Nicole                                              1
#  2 THE EXTREME,Master Chief & iLLest Game,,52\n...        1
#
# [222363 rows x 1 columns]

# %%
artist_avg_song_len = (songs[['artist_name','song_length']].groupby(['artist_name']).mean()/1000).sort_values('song_length', ascending=False)

# %%
test = songs[['artist_name','song_id','language']].groupby(['artist_name','language']).count()
test.reset_index(level=['artist_name','language'],inplace=True)
test['count_max']=test.groupby(['artist_name'])['song_id'].transform(max)
artist_max_song_language = test.loc[test["song_id"] == test["count_max"]]
artist_max_song_language.reset_index(drop=True)
artist_max_song_language.sort_values('count_max',ascending=False)
# Out:
#                                               artist_name    ...      count_max
# 212639                                    Various Artists    ...          93881
# 238714                                 証聲音樂圖書館 ECHO MUSIC    ...           8888
# 228521                                          รวมศิลปิน    ...           4085
# 23970                                        Billy Vaughn    ...           3940
# 62350                                       Elvis Presley    ...           3907
# 70269                                       Frank Sinatra    ...           3071
# 164855                                 Richard Clayderman    ...           3018
# 140553                                      Nat King Cole    ...           2896
# 14803                                    Armin van Buuren    ...           2775
# 23731                                      Billie Holiday    ...           2694
# 229594                                    オルゴールサウンド J-POP    ...           2687
# 76070                                         Glenn Gould    ...           2585
# 25807                                           Bob Dylan    ...           2388
# 131482                                    Michael Jackson    ...           2173
# 66427                               Falcom Sound Team jdk    ...           2163
# 62005                                     Ella Fitzgerald    ...           2076
# 161982                                        Ray Charles    ...           2043
# 219322                            Wolfgang Amadeus Mozart    ...           2011
# 12122                                       Andy Williams    ...           1903
# 35389                                          Chet Baker    ...           1876
# 240372                                         霹靂布袋戲劇集原聲帶    ...           1835
# 221583                                           Yo-Yo Ma    ...           1781
# 239327                                  鄧麗君 (Teresa Teng)    ...           1738
# 212611                                            Various    ...           1737
# 70843                                     Frederic Chopin    ...           1687
# 13774                                     Antonio Vivaldi    ...           1658
# 23601                                          Bill Evans    ...           1647
# 101667                                       Julie London    ...           1591
# 157561                                Power Music Workout    ...           1572
# 17540                                           B.B. King    ...           1535
# ...                                                   ...    ...            ...
# 121403                                                M80    ...              1
# 20209                                          Bass Waves    ...              1
# 121406                                                M87    ...              1
# 121407                                               M@rz    ...              1
# 121411                                          MA-TE LIN    ...              1
# 121371                                             M.Waxx    ...              1
# 121414                                         MAAE| Maae    ...              1
# 121415                                               MAAK    ...              1
# 121418                                      MAAMI (MAAMI)    ...              1
# 121420                                               MAAT    ...              1
# 121423                                               MAC3    ...              1
# 121424           MACCHO(from OZROSAURUS)，Norikiyo，般若＆DABO    ...              1
# 121395                                              M3TRO    ...              1
# 121393                                                M3H    ...              1
# 121391                                    M3 MusicMakesMe    ...              1
# 121390                                                 M3    ...              1
# 20211                                              Bass-T    ...              1
# 121388                                                 M2    ...              1
# 121387  M1KRONAUT| Double Reaktion| KAPEG| David Orteg...    ...              1
# 121386                                 M1GZZ| Minor Editz    ...              1
# 121385                                               M185    ...              1
# 121384                         M16 & The Full Moon Wolves    ...              1
# 121383                                         M1 Theking    ...              1
# 121381                                          M.rellion    ...              1
# 121378                                M.in & Senjor Rossi    ...              1
# 121377                                  M.in & Jonas Fahz    ...              1
# 121376                                         M.i.c.r.o.    ...              1
# 121374                                             M.a.T.    ...              1
# 121373                                                M.Y    ...              1
# 0        2 THE EXTREME,Master Chief & iLLest Game,,52\...    ...              1
#
# [225062 rows x 4 columns]

# %%
test = songs[['artist_name','song_id','genre_ids']].groupby(['artist_name','genre_ids']).count()
test.reset_index(level=['artist_name','genre_ids'],inplace=True)
test['count_max']=test.groupby(['artist_name'])['song_id'].transform(max)
artist_max_song_genre = test.loc[test["song_id"] == test["count_max"]]
artist_max_song_genre.reset_index(drop=True)
artist_max_song_genre.sort_values('count_max',ascending=False)
# Out:
#                                   artist_name    ...    count_max
# 241692                        Various Artists    ...        24753
# 270535                     証聲音樂圖書館 ECHO MUSIC    ...         3227
# 186847                     Richard Clayderman    ...         2863
# 16733                        Armin van Buuren    ...         2658
# 26971                          Billie Holiday    ...         2461
# 86454                             Glenn Gould    ...         2389
# 26803                              Bill Evans    ...         2388
# 27282                            Billy Vaughn    ...         2296
# 40430                              Chet Baker    ...         2275
# 75289                   Falcom Sound Team jdk    ...         2148
# 223957                          The Kiboomers    ...         2113
# 70157                         Ella Fitzgerald    ...         2006
# 149233                        Michael Jackson    ...         1930
# 159448                          Nat King Cole    ...         1921
# 249741                Wolfgang Amadeus Mozart    ...         1902
# 178617                    Power Music Workout    ...         1853
# 134946                        Louis Armstrong    ...         1799
# 252300                               Yo-Yo Ma    ...         1768
# 271273                      鄧麗君 (Teresa Teng)    ...         1700
# 15565                         Antonio Vivaldi    ...         1681
# 151278                            Miles Davis    ...         1680
# 272389                             霹靂布袋戲劇集原聲帶    ...         1591
# 80489                         Frederic Chopin    ...         1495
# 79761                           Frank Sinatra    ...         1488
# 70592                           Elvis Presley    ...         1396
# 262080                                 內地華語精選    ...         1384
# 111321                  Johann Sebastian Bach    ...         1382
# 208377                              Stan Getz    ...         1369
# 54357                        Daniel Barenboim    ...         1369
# 163177                   Nikolaus Harnoncourt    ...         1363
# ...                                       ...    ...          ...
# 120611                           Kenny Turnup    ...            1
# 120615                            Kenny Wayne    ...            1
# 120622                       Kenny Wellington    ...            1
# 120624                      Kenny Werner Trio    ...            1
# 120630                            Kenny White    ...            1
# 120631                         Kenny Williams    ...            1
# 120632                           Kenny Wilson    ...            1
# 120636                       KennyMackForever    ...            1
# 120638                       KennyMuoreSempre    ...            1
# 120643                               Keno Don    ...            1
# 120644                                Kenosis    ...            1
# 120604                            Kenny Smith    ...            1
# 120603                          Kenny Simmons    ...            1
# 120602                            Kenny Shane    ...            1
# 120576                          Kenny Margant    ...            1
# 120557                              Kenny Jay    ...            1
# 120561  Kenny Laakkinen feat. Yesterdays Fate    ...            1
# 120562                           Kenny Lamour    ...            1
# 120563              Kenny Larkin| Shlomi Aber    ...            1
# 120574                          Kenny MacLean    ...            1
# 120575      Kenny Mack and the Soul Searchers    ...            1
# 120577                      Kenny Martin Band    ...            1
# 120601                           Kenny Selcer    ...            1
# 120578                          Kenny Munshaw    ...            1
# 120581                                Kenny P    ...            1
# 120582                               Kenny P.    ...            1
# 120583                          Kenny Peagler    ...            1
# 120587                              Kenny Ray    ...            1
# 120600                          Kenny Sargent    ...            1
# 137009                          Luther Sticky    ...            1
#
# [222608 rows x 4 columns]

# %%
# %matplotlib inline

import pandas
from sklearn.model_selection import train_test_split
import numpy as np
import time
from sklearn.externals import joblib
#from recommenders import Recommenders as Recommenders
#from recommenders import Evaluation as Evaluation
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from subprocess import check_output
#print(check_output(["ls", "C:\\Users\\Vineel\\Documents\\RecommenderSystems_PyData_2016-master\\input"]).decode("utf8"))

# %%
#Class to calculate precision and recall

import random

class precision_recall_calculator():
    
    def __init__(self, test_data, train_data, pm, is_model):
        self.test_data = test_data
        self.train_data = train_data
        self.user_test_sample = None
        self.model1 = pm
        self.model2 = is_model
        
        self.ism_training_dict = dict()
        self.pm_training_dict = dict()
        self.test_dict = dict()
    
    #Method to return random percentage of values from a list
    def remove_percentage(self, list_a, percentage):
        k = int(len(list_a) * percentage)
        random.seed(0)
        indicies = random.sample(range(len(list_a)), k)
        new_list = [list_a[i] for i in indicies]
    
        return new_list
    
    #Create a test sample of users for use in calculating precision
    #and recall
    def create_user_test_sample(self, percentage):
        #Find users common between training and test set
        users_test_and_training = list(set(self.test_data['user_id'].unique()).intersection(set(self.train_data['user_id'].unique())))
        print("Length of user_test_and_training:%d" % len(users_test_and_training))

        #Take only random user_sample of users for evaluations
        self.users_test_sample = self.remove_percentage(users_test_and_training, percentage)

        print("Length of user sample:%d" % len(self.users_test_sample))
        
    #Method to generate recommendations for users in the user test sample
    def get_test_sample_recommendations(self):
        #For these test_sample users, get top 10 recommendations from training set
        #self.ism_training_dict = {}
        #self.pm_training_dict = {}

        #self.test_dict = {}

        for user_id in self.users_test_sample:
            #Get items for user_id from item similarity model
            print("Getting recommendations for user:%s" % user_id)
            user_sim_items = self.model2.recommend(user_id)
            self.ism_training_dict[user_id] = list(user_sim_items["song"])
    
            #Get items for user_id from popularity model
            user_sim_items = self.model1.recommend(user_id)
            self.pm_training_dict[user_id] = list(user_sim_items["song"])
    
            #Get items for user_id from test_data
            test_data_user = self.test_data[self.test_data['user_id'] == user_id]
            self.test_dict[user_id] = set(test_data_user['song'].unique() )
    
    #Method to calculate the precision and recall measures
    def calculate_precision_recall(self):
        #Create cutoff list for precision and recall calculation
        cutoff_list = list(range(1,11))


        #For each distinct cutoff:
        #    1. For each distinct user, calculate precision and recall.
        #    2. Calculate average precision and recall.

        ism_avg_precision_list = []
        ism_avg_recall_list = []
        pm_avg_precision_list = []
        pm_avg_recall_list = []


        num_users_sample = len(self.users_test_sample)
        for N in cutoff_list:
            ism_sum_precision = 0
            ism_sum_recall = 0
            pm_sum_precision = 0
            pm_sum_recall = 0
            ism_avg_precision = 0
            ism_avg_recall = 0
            pm_avg_precision = 0
            pm_avg_recall = 0

            for user_id in self.users_test_sample:
                ism_hitset = self.test_dict[user_id].intersection(set(self.ism_training_dict[user_id][0:N]))
                pm_hitset = self.test_dict[user_id].intersection(set(self.pm_training_dict[user_id][0:N]))
                testset = self.test_dict[user_id]
        
                pm_sum_precision += float(len(pm_hitset))/float(N)
                pm_sum_recall += float(len(pm_hitset))/float(len(testset))

                ism_sum_precision += float(len(ism_hitset))/float(len(testset))
                ism_sum_recall += float(len(ism_hitset))/float(N)
        
            pm_avg_precision = pm_sum_precision/float(num_users_sample)
            pm_avg_recall = pm_sum_recall/float(num_users_sample)
    
            ism_avg_precision = ism_sum_precision/float(num_users_sample)
            ism_avg_recall = ism_sum_recall/float(num_users_sample)

            ism_avg_precision_list.append(ism_avg_precision)
            ism_avg_recall_list.append(ism_avg_recall)
    
            pm_avg_precision_list.append(pm_avg_precision)
            pm_avg_recall_list.append(pm_avg_recall)
            
        return (pm_avg_precision_list, pm_avg_recall_list, ism_avg_precision_list, ism_avg_recall_list)
     

    #A wrapper method to calculate all the evaluation measures
    def calculate_measures(self, percentage):
        #Create a test sample of users
        self.create_user_test_sample(percentage)
        
        #Generate recommendations for the test sample users
        self.get_test_sample_recommendations()
        
        #Calculate precision and recall at different cutoff values
        #for popularity mode (pm) as well as item similarity model (ism)
        
        return self.calculate_precision_recall()
        #return (pm_avg_precision_list, pm_avg_recall_list, ism_avg_precision_list, ism_avg_recall_list)

# %%
import numpy as np
import pandas

#Class for Popularity based Recommender System model
class popularity_recommender_py():
    def __init__(self):
        self.train_data = None
        self.user_id = None
        self.item_id = None
        self.popularity_recommendations = None
        
    #Create the popularity based recommender system model
    def create(self, train_data, user_id, item_id):
        self.train_data = train_data
        self.user_id = user_id
        self.item_id = item_id

        #Get a count of user_ids for each unique song as recommendation score
        train_data_grouped = train_data.groupby([self.item_id]).agg({self.user_id: 'count'}).reset_index()
        train_data_grouped.rename(columns = {'user_id': 'score'},inplace=True)
    
        #Sort the songs based upon recommendation score
        train_data_sort = train_data_grouped.sort_values(['score', self.item_id], ascending = [0,1])
    
        #Generate a recommendation rank based upon score
        train_data_sort['Rank'] = train_data_sort['score'].rank(ascending=0, method='first')
        
        #Get the top 10 recommendations
        self.popularity_recommendations = train_data_sort.head(10)

    #Use the popularity based recommender system model to
    #make recommendations
    def recommend(self, user_id):    
        user_recommendations = self.popularity_recommendations
        
        #Add user_id column for which the recommendations are being generated
        user_recommendations['user_id'] = user_id
    
        #Bring user_id column to the front
        cols = user_recommendations.columns.tolist()
        cols = cols[-1:] + cols[:-1]
        user_recommendations = user_recommendations[cols]
        
        return user_recommendations
    

#Class for Item similarity based Recommender System model
class item_similarity_recommender_py():
    def __init__(self):
        self.train_data = None
        self.user_id = None
        self.item_id = None
        self.cooccurence_matrix = None
        self.songs_dict = None
        self.rev_songs_dict = None
        self.item_similarity_recommendations = None
        
    #Get unique items (songs) corresponding to a given user
    def get_user_items(self, user):
        user_data = self.train_data[self.train_data[self.user_id] == user]
        user_items = list(user_data[self.item_id].unique())
        
        return user_items
        
    #Get unique users for a given item (song)
    def get_item_users(self, item):
        item_data = self.train_data[self.train_data[self.item_id] == item]
        item_users = set(item_data[self.user_id].unique())
            
        return item_users
        
    #Get unique items (songs) in the training data
    def get_all_items_train_data(self):
        all_items = list(self.train_data[self.item_id].unique())
            
        return all_items
        
    #Construct cooccurence matrix
    def construct_cooccurence_matrix(self, user_songs, all_songs):
            
        ####################################
        #Get users for all songs in user_songs.
        ####################################
        user_songs_users = []        
        for i in range(0, len(user_songs)):
            user_songs_users.append(self.get_item_users(user_songs[i]))
            
        ###############################################
        #Initialize the item cooccurence matrix of size 
        #len(user_songs) X len(songs)
        ###############################################
        cooccurence_matrix = np.matrix(np.zeros(shape=(len(user_songs), len(all_songs))), float)
           
        #############################################################
        #Calculate similarity between user songs and all unique songs
        #in the training data
        #############################################################
        for i in range(0,len(all_songs)):
            #Calculate unique listeners (users) of song (item) i
            songs_i_data = self.train_data[self.train_data[self.item_id] == all_songs[i]]
            users_i = set(songs_i_data[self.user_id].unique())
            
            for j in range(0,len(user_songs)):       
                    
                #Get unique listeners (users) of song (item) j
                users_j = user_songs_users[j]
                    
                #Calculate intersection of listeners of songs i and j
                users_intersection = users_i.intersection(users_j)
                
                #Calculate cooccurence_matrix[i,j] as Jaccard Index
                if len(users_intersection) != 0:
                    #Calculate union of listeners of songs i and j
                    users_union = users_i.union(users_j)
                    
                    cooccurence_matrix[j,i] = float(len(users_intersection))/float(len(users_union))
                else:
                    cooccurence_matrix[j,i] = 0
                    
        
        return cooccurence_matrix

    
    #Use the cooccurence matrix to make top recommendations
    def generate_top_recommendations(self, user, cooccurence_matrix, all_songs, user_songs):
        print("Non zero values in cooccurence_matrix :%d" % np.count_nonzero(cooccurence_matrix))
        
        #Calculate a weighted average of the scores in cooccurence matrix for all user songs.
        user_sim_scores = cooccurence_matrix.sum(axis=0)/float(cooccurence_matrix.shape[0])
        user_sim_scores = np.array(user_sim_scores)[0].tolist()
 
        #Sort the indices of user_sim_scores based upon their value
        #Also maintain the corresponding score
        sort_index = sorted(((e,i) for i,e in enumerate(list(user_sim_scores))), reverse=True)
    
        #Create a dataframe from the following
        columns = ['user_id', 'song', 'score', 'rank']
        #index = np.arange(1) # array of numbers for the number of samples
        df = pandas.DataFrame(columns=columns)
         
        #Fill the dataframe with top 10 item based recommendations
        rank = 1 
        for i in range(0,len(sort_index)):
            if ~np.isnan(sort_index[i][0]) and all_songs[sort_index[i][1]] not in user_songs and rank <= 10:
                df.loc[len(df)]=[user,all_songs[sort_index[i][1]],sort_index[i][0],rank]
                rank = rank+1
        
        #Handle the case where there are no recommendations
        if df.shape[0] == 0:
            print("The current user has no songs for training the item similarity based recommendation model.")
            return -1
        else:
            return df
 
    #Create the item similarity based recommender system model
    def create(self, train_data, user_id, item_id):
        self.train_data = train_data
        self.user_id = user_id
        self.item_id = item_id

    #Use the item similarity based recommender system model to
    #make recommendations
    def recommend(self, user):
        
        ########################################
        #A. Get all unique songs for this user
        ########################################
        user_songs = self.get_user_items(user)    
            
        print("No. of unique artists for the user: %d" % len(user_songs))
        
        ######################################################
        #B. Get all unique items (songs) in the training data
        ######################################################
        all_songs = self.get_all_items_train_data()
        
        print("no. of unique artists in the training set: %d" % len(all_songs))
         
        ###############################################
        #C. Construct item cooccurence matrix of size 
        #len(user_songs) X len(songs)
        ###############################################
        cooccurence_matrix = self.construct_cooccurence_matrix(user_songs, all_songs)
        
        #######################################################
        #D. Use the cooccurence matrix to make recommendations
        #######################################################
        df_recommendations = self.generate_top_recommendations(user, cooccurence_matrix, all_songs, user_songs)
                
        return df_recommendations
    
    #Get similar items to given items
    def get_similar_items(self, item_list):
        
        user_songs = item_list
        
        ######################################################
        #B. Get all unique items (songs) in the training data
        ######################################################
        all_songs = self.get_all_items_train_data()
        
        print("no. of unique artists in the training set: %d" % len(all_songs))
         
        ###############################################
        #C. Construct item cooccurence matrix of size 
        #len(user_songs) X len(songs)
        ###############################################
        cooccurence_matrix = self.construct_cooccurence_matrix(user_songs, all_songs)
        
        #######################################################
        #D. Use the cooccurence matrix to make recommendations
        #######################################################
        user = ""
        df_recommendations = self.generate_top_recommendations(user, cooccurence_matrix, all_songs, user_songs)
         
        return df_recommendations

# %%
train = pd.read_csv('../input/train.csv')

songs = pd.read_csv('../input//songs.csv')
test = pd.read_csv('../input//test.csv')
members = pd.read_csv('../input//members.csv')
songs_extra_info = pd.read_csv('../input/song_extra_info.csv')

# %%
df = train.merge(members,how='inner',on='msno')
df = df.merge(songs,how='inner',on='song_id')
df = df.merge(songs_extra_info,how='inner',on='song_id')
df.drop_duplicates(subset =['source_system_tab', 'source_screen_name',
       'source_type', 'target', 'city', 'bd', 'gender', 'registered_via',
       'registration_init_time', 'expiration_date', 'song_length', 'genre_ids',
       'artist_name', 'composer', 'lyricist', 'language'], 
                     keep = False, inplace = True) 
df.reset_index(drop = True,inplace=True)
df
# Out:
#                                                  msno      ...               isrc
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=      ...       GBUM71602854
# 1        pouJqjNRmZOnRNzzMWWkamTKkIGHyvhl/jo4HgbncnM=      ...       GBUM71602854
# 2        xbodnNBaLMyqqI7uFJlvHOKMJaizuWo/BB/YHZICcKo=      ...       GBUM71602854
# 3        s0ndDsjI79amU0RBiullFN8HRz9HjE++34jGNa7zJ/s=      ...       GBUM71602854
# 4        Vw4Umh6/qlsJDC/XMslyAxVvRgFJGHr53yb/nrmY1DU=      ...       GBUM71602854
# 5        YqtKhiDOFJ/gdd2V4AFdnVwGMMaA0yUEbb8w7xuoP7I=      ...       GBUM71602854
# 6        jGiECz8y+oKS0tDcZArJXK2ZQisBpk/OC3wh4kvs8gc=      ...       GBUM71602854
# 7        ruQx4VOdTq74CDI1viGqQAIASWrU4soi74t1E3N6KO4=      ...       GBUM71602854
# 8        7xiBI5xU3P2/IiR9teB7jySfzWo96JGikGajteLd3Cs=      ...       GBUM71602854
# 9        z2IYoGWjJJPv4ySp+1lCIfU1APu2YRHsjY2sy2ehq0k=      ...       GBUM71602854
# 10       oKMHFr1nozVUOW4TP9bcbtVhgCt5gh+22fJ1mUXx9eM=      ...       GBUM71602854
# 11       e5Ezre9HPuPos+CXQXtmo32E/hHIZTMmo6jG3yRf6UA=      ...       GBUM71602854
# 12       tlFGRF/TtrSwJA9XPHL4cajWghZCbAbhzif/6wJiN6Q=      ...       GBUM71602854
# 13       Gytn0lz9OGR2vGl/tSXA3rDUcNnU4TnxFcWb+iv2pXc=      ...       GBUM71602854
# 14       pRHIP4XdwWx7YpREsLN4sD0gb2BUEbhKytDXlwUAO+k=      ...       GBUM71602854
# 15       vf72WjMnAjr9ELP36xOjbCXhXQTk2qCQ1MW56xKT12s=      ...       GBUM71602854
# 16       cArsboqFz/6anddpnMwh2OptGbYB+mT3yeSNV7XxrRA=      ...       GBUM71602854
# 17       ERpPeskmIkU3MrJxl9BQjGn2a/Nqv72E77hFyxQ8iY8=      ...       GBUM71602854
# 18       8Hh8B3UZRBATg+WAHfE+sZ2hHeqT7QMDr8PdiWFPESE=      ...       GBUM71602854
# 19       /tFG33EMQ6m1ZBY2RbFIqKqyhwqnx8qL1VzHdWkAuMA=      ...       GBUM71602854
# 20       a1d2KnoIq+/QdPaHUojFU7jnze1HDUxu5VFHJ2hti2w=      ...       GBUM71602854
# 21       MfpAwtL9uoZ+5z/zTuGOcGbNh45v7MeJ+cbJlb/14X4=      ...       GBUM71602854
# 22       MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=      ...       GBUM71602854
# 23       Zy0Nxvr1rTLpf85L79dMsVF6mPvVY3YgN6TgNwza7oI=      ...       GBUM71602854
# 24       wlGXXGn+a4va5/R4HWuk+ttkMp48ccj5FRjjPLAh2mI=      ...       GBUM71602854
# 25       R7AyK9ZUi5d21sCDumgghXW+TNacd/qN0dNMa0C22pA=      ...       GBUM71602854
# 26       kOXcer+//oOLtOB6JLhxNqj/3YyTH2m+kWfvYTtMc7I=      ...       GBUM71602854
# 27       CQSbIGpOs0ZOz578sAij/5djDLEnvAsxAtfByXc9JiU=      ...       GBUM71602854
# 28       yCsfLrK6TZNPAPbu0TFv+kwv/3CFTNMGRFpFCahPiqs=      ...       GBUM71602854
# 29       1NBzQ4hbG65uz/esF0hMF9kXDLTNKLdI06S06nJZ/Kk=      ...       GBUM71602854
# ...                                               ...      ...                ...
# 7321821  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USQY51145387
# 7321822  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USA371049649
# 7321823  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USA561350558
# 7321824  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USTC60827899
# 7321825  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USASN1201527
# 7321826  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USASN1201514
# 7321827  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       GB32E1304680
# 7321828  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USZHR1600033
# 7321829  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USIR10300221
# 7321830  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       GB32E1400197
# 7321831  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       GB32E1304681
# 7321832  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       KRA351303473
# 7321833  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USA561350561
# 7321834  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USSM10022820
# 7321835  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USHKR0915911
# 7321836  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USA561298980
# 7321837  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       JPWP01371631
# 7321838  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USA561091151
# 7321839  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       JPWP01500990
# 7321840  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USBWK0700052
# 7321841  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USFP71227011
# 7321842  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=      ...       USSM10025030
# 7321843  EwQCy6vvSqKWBYZuSB/xofq1h8nBT9ZYaWEFymts4t0=      ...       USEGX1319080
# 7321844  4jdyQwahZh2lhs08UdnDbu+DqaCJgoPFOrPp83W+044=      ...       USG7D1644802
# 7321845  b+zlHeMVMrhQObGieK6wDNRuoe8heCGVYD74kejsxyk=      ...       USQ4E1602140
# 7321846  QPrVEVrWZBD2+QNPnzxHWAUUHd2IpicbPcd99Eqf7LY=      ...       TWU711601432
# 7321847  Bz0puqoyfJ+pjRAH0UZy6TUaZyoNyH6vrFs97ivG/0c=      ...       GBBKS1100031
# 7321848  vKFLRCvickoFcCoGgv5BT/kuH/XWqofuTm9JWkaFybM=      ...       HKH611500046
# 7321849  IAUJlwmr/sjXUg+mHdWpLIjeFLkS0nv3kE5SI6xipuQ=      ...       HKD251016208
# 7321850  IAUJlwmr/sjXUg+mHdWpLIjeFLkS0nv3kE5SI6xipuQ=      ...       MYHY11600264
#
# [7321851 rows x 20 columns]

# %%
sa=df[['msno','song_id','artist_name']]


sa = sa.groupby(['msno','artist_name']).count()
sa.reset_index(inplace =True)

# %%
sa.columns = ['user_id','song_id','listen_count']
sa
# Out:
#                                               user_id     ...      listen_count
# 0        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 4
# 1        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 2        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 3        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 3
# 4        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                18
# 5        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 6        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 7        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                47
# 8        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 9        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 10       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 2
# 11       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 12       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 13       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 3
# 14       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 3
# 15       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                34
# 16       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 2
# 17       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 18       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 19       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 20       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 21       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 22       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 23       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                20
# 24       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 25       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 26       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 27       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 28       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                 1
# 29       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=     ...                14
# ...                                               ...     ...               ...
# 3104871  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                11
# 3104872  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104873  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104874  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104875  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104876  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104877  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104878  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104879  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104880  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104881  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104882  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104883  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104884  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104885  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104886  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104887  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104888  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104889  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104890  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104891  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 2
# 3104892  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104893  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104894  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104895  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 4
# 3104896  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 1
# 3104897  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     ...                 3
# 3104898  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=     ...                 1
# 3104899  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=     ...                 1
# 3104900  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=     ...                 1
#
# [3104901 rows x 3 columns]

# %%
#df = sa.head(len(sa))
df = sa.head(50000)
song_grouped = df.groupby(['song_id']).agg({'listen_count': 'count'}).reset_index()
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage']  = song_grouped['listen_count'].div(grouped_sum)*100
song_grouped.sort_values(['listen_count', 'song_id'], ascending = [0,1])
# Out:
#                                song_id  listen_count  percentage
# 4651                   Various Artists           372       0.744
# 5282                    周杰倫 (Jay Chou)           297       0.594
# 6168                        田馥甄 (Hebe)           291       0.582
# 5071                      五月天 (Mayday)           285       0.570
# 5861                      林俊傑 (JJ Lin)           276       0.552
# 6720                  陳奕迅 (Eason Chan)           254       0.508
# 1601                         G.E.M.鄧紫棋           250       0.500
# 4911                        aMEI (張惠妹)           250       0.500
# 6501                     謝和弦 (R-chord)           241       0.482
# 1438                          Eric 周興哲           239       0.478
# 5287                 周湯豪 (NICKTHEREAL)           216       0.432
# 195                        Alan Walker           205       0.410
# 4258                  The Chainsmokers           201       0.402
# 2895                          Maroon 5           200       0.400
# 5038                        丁噹 (Della)           198       0.396
# 5254                    吳克群 (Kenji Wu)           197       0.394
# 6153                               玖壹壹           195       0.390
# 6710                  陳勢安 (Andrew Tan)           192       0.384
# 6814                 韋禮安 (William Wei)           189       0.378
# 96                               A-Lin           187       0.374
# 5135    兄弟本色G.U.T.S. (姚中仁、張震嶽、頑童MJ116)           181       0.362
# 5880                    林宥嘉 (Yoga Lin)           180       0.360
# 5937                 楊丞琳 (Rainie Yang)           176       0.352
# 737                       CHARLIE PUTH           174       0.348
# 5811                               李榮浩           174       0.348
# 5433                     孫盛希 (Shi Shi)           173       0.346
# 6432                   蘇打綠 (Sodagreen)           173       0.346
# 5143  八三夭 (The Last Day of Summer 831)           171       0.342
# 445                            BIGBANG           170       0.340
# 6595                   郭靜 (Claire Kuo)           170       0.340
# ...                                ...           ...         ...
# 6922                 黃舒駿 (Jerry Huang)             1       0.002
# 6924                               黃裕翔             1       0.002
# 6926                               黃金佑             1       0.002
# 6927                             黃金典藏輯             1       0.002
# 6928                               黃鎮炘             1       0.002
# 6930                               黃露儀             1       0.002
# 6933                           黃韻玲+洪筠惠             1       0.002
# 6934                               黃鳳嬌             1       0.002
# 6937                               黃麗卿             1       0.002
# 6944                              黒うさP             1       0.002
# 6945                              黛青塔娜             1       0.002
# 6954                               구하라             1       0.002
# 6955                       긱스|소유 (씨스타)             1       0.002
# 6956                          릴보이| 베이식             1       0.002
# 6958                              물고기꿈             1       0.002
# 6959                               박세환             1       0.002
# 6960                               박재민             1       0.002
# 6962                               박지섭             1       0.002
# 6964                              샘 카터             1       0.002
# 6966                        소유| 매드 클라운             1       0.002
# 6967                        손담비| 애프터스쿨             1       0.002
# 6969                           슬리피&송지은             1       0.002
# 6971                               이승윤             1       0.002
# 6972                               이재량             1       0.002
# 6973                           일렉트로보이즈             1       0.002
# 6975                     제8극장 Theatre8             1       0.002
# 6976                       지아&이해리(다비치)             1       0.002
# 6979                             허각&지아             1       0.002
# 6980                          허각| 브로맨스             1       0.002
# 6981                               황수정             1       0.002
#
# [6982 rows x 3 columns]

# %%
###Fill in the code here
songs = sa['song_id'].unique()
len(songs)
# Out:
# 40545

# %%
train_data, test_data = train_test_split(sa, test_size = 0.95, random_state=0)
print(train_data.head(5))
# Out:
#                                               user_id     ...      listen_count
# 334662   4xYDQR5qgjrOipOG3HeNW+2gz6cQ03RTV3XNEiOe6Is=     ...                 1
# 2660219  qv24DyXUmZVHzxwcgPJRy7qFeni3fdd2q47kxiCekjs=     ...                 1
# 418614   6fGAUf1BJeTefYr5PUdmJVQ80DWsKr/3JRIf2w9MGAk=     ...                 1
# 2870909  v3iWj2uNYuVPKwMYOpV2y1h4YXZBHbsE7rCJkkdncr4=     ...                 1
# 246225   36ssOis3i3hOUACW6qxG9wNO0BEeATRkNVx9qAAnNNE=     ...                 1
#
# [5 rows x 3 columns]

# %%
pm = popularity_recommender_py()
pm.create(train_data, 'user_id', 'song_id')

# %%
id = members.iloc[6]['msno']
#user_id = users[5]
pm.recommend(id)
# Out:
#                                             user_id  ...   Rank
# 8364   Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    1.0
# 9132   Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    2.0
# 9455   Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    3.0
# 10247  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    4.0
# 10679  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    5.0
# 2831   Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    6.0
# 11139  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    7.0
# 11444  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    8.0
# 2525   Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...    9.0
# 9461   Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=  ...   10.0
#
# [10 rows x 4 columns]

# %%
is_model = item_similarity_recommender_py()
is_model.create(train_data, 'user_id', 'song_id')

# %%
#Print the songs for the user in training data
user_id = members.iloc[7]['msno']
user_items = is_model.get_user_items(user_id)
#
print("------------------------------------------------------------------------------------")
print("Training data artists for the user msno: %s:" % user_id)
print("------------------------------------------------------------------------------------")

for user_item in user_items:
    print(user_item)

print("----------------------------------------------------------------------")
print("Recommendation process going on:")
print("----------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------------------------
# Training data artists for the user msno: pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=:
# ------------------------------------------------------------------------------------
# DJ COOL & die 7 Zwerge
# Alan Walker
# Sam Smith
# Crispy脆樂團
# JAZZ CAFÉ
# David Guetta
# John Mayer
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------

# %%
#7
#Recommend songs for the user using personalized model
is_model.recommend(user_id)
# Out:
# No. of unique artists for the user: 7
# no. of unique artists in the training set: 11839
# Non zero values in cooccurence_matrix :5950
#                                         user_id ...  rank
# 0  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     1
# 1  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     2
# 2  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     3
# 3  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     4
# 4  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     5
# 5  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     6
# 6  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     7
# 7  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     8
# 8  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     9
# 9  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...    10
#
# [10 rows x 4 columns]

# %%
#Print the songs for the user in training data
user_id = members.iloc[7]['msno']
user_items = is_model.get_user_items(user_id)
#
print("------------------------------------------------------------------------------------")
print("Training data artists for the user msno: %s:" % user_id)
print("------------------------------------------------------------------------------------")

for user_item in user_items:
    print(user_item)

print("----------------------------------------------------------------------")
print("Recommendation process going on:")
print("----------------------------------------------------------------------")

is_model.recommend(user_id)
# Out:
# ------------------------------------------------------------------------------------
# Training data artists for the user msno: pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=:
# ------------------------------------------------------------------------------------
# DJ COOL & die 7 Zwerge
# Alan Walker
# Sam Smith
# Crispy脆樂團
# JAZZ CAFÉ
# David Guetta
# John Mayer
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------
# No. of unique artists for the user: 7
# no. of unique artists in the training set: 11839
# Non zero values in cooccurence_matrix :5950
#                                         user_id ...  rank
# 0  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     1
# 1  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     2
# 2  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     3
# 3  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     4
# 4  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     5
# 5  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     6
# 6  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     7
# 7  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     8
# 8  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...     9
# 9  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY= ...    10
#
# [10 rows x 4 columns]
